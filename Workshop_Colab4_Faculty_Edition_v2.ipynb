# %% [markdown]
# # Workflow Automation, Metadata, Provenance, and Reproducible Research
#
# # FACULTY EDITION v2

# %% [markdown]
# ## Teaching Narrative
# This notebook is the reproducibility core of the workshop. Students learn that reproducibility is an architectural property of workflows, not an afterthought.

# %% [markdown]
# ## Workshop Context
# Colab 1: Workflow Foundations
# Colab 2: Data Repositories
# Colab 3: Analysis and Visualization
# Colab 4: Automation, Metadata, Provenance, and Reproducibility

# %% [markdown]
# ## NSF CyberTraining Alignment
# Reproducible science, data stewardship, metadata management, provenance capture, FAIR practices, and workflow automation.

# %% [markdown]
# ## Learning Outcomes
# - Explain reproducibility concepts
# - Create metadata inventories
# - Document provenance
# - Build workflow logs
# - Evaluate FAIR compliance

# %% [markdown]
# ## Instructor Delivery Guide
# 0-10 Motivation
# 10-25 Metadata
# 25-40 Provenance
# 40-55 Workflow Logging
# 55-70 FAIR Assessment
# 70-80 Reflection

# %% [markdown]
# ## Activity Timing Guide
# Metadata Inventory: 15 min
# Provenance Record: 15 min
# Workflow Logging: 15 min
# FAIR Review: 15 min

# %% [markdown]
# ## Instructor Background
# Researchers frequently fail to document versions, parameters, environments, and AI usage. Reproducibility failures often originate in poor workflow documentation.

# %% [markdown]
# ## Common Misconceptions
# 1. Saving code guarantees reproducibility.
# 2. Metadata are optional.
# 3. FAIR means correct.
# 4. Automation and reproducibility are unrelated.

# %%
import pandas as pd
url="https://raw.githubusercontent.com/OpenNeuroDatasets/ds000247/main/participants.tsv"
df=pd.read_csv(url,sep="\t")
df.head()

# %% [markdown]
# ## Activity 1: Metadata Inventory
# Students create a metadata inventory describing datasets, variables, versions, and usage context.

# %% [markdown]
# ### Faculty Solution
# Inventory should include source, repository, dataset identifier, variables, missing data notes, software versions, and access date.

# %%
metadata_inventory={"rows":"example","columns":"example"}
metadata_inventory

# %% [markdown]
# ## Facilitation Notes
# Ask students what information future researchers would need to repeat the work in five years.

# %% [markdown]
# ## Provenance Concepts
# Provenance captures where data originated, how it was transformed, what tools were used, and how outputs were generated.

# %% [markdown]
# ## Activity 2 Faculty Solution
# Provenance records should include dataset source, version, processing steps, software environment, parameters, and outputs.

# %%
import platform
workflow_log={"python_version":platform.python_version()}
workflow_log

# %% [markdown]
# ## Workflow Logging Framework
# Document inputs, transformations, parameters, environment, AI usage, generated outputs, and timestamps.

# %% [markdown]
# ## FAIR Assessment Framework
# Findable, Accessible, Interoperable, Reusable. Require evidence rather than assumptions.

# %% [markdown]
# ## Strong Student Response
# Connects metadata, provenance, FAIR principles, and reproducibility into a coherent workflow explanation.

# %% [markdown]
# ## Average Student Response
# Documents workflow steps but omits environment and provenance details.

# %% [markdown]
# ## Weak Student Response
# Focuses only on code execution.

# %% [markdown]
# ## Reproducibility Failure Case Study
# Discuss how missing versions, undocumented preprocessing, or missing parameters prevent replication.

# %% [markdown]
# ## Discussion Prompts
# - What information is necessary for replication?
# - What is the difference between metadata and provenance?
# - Can FAIR data still be difficult to reproduce?
# - How should AI interactions be documented?

# %% [markdown]
# ## AI Facilitation Guide
# Prompt: Generate a reproducibility checklist for this workflow. Critique completeness and omissions.

# %% [markdown]
# ## Common AI Hallucinations
# - Inventing versions
# - Assuming FAIR compliance
# - Claiming reproducibility without evidence
# - Ignoring software dependencies

# %% [markdown]
# ## Sample Student Artifact
# Includes metadata inventory, provenance report, workflow log, FAIR assessment, and reproducibility reflection.

# %% [markdown]
# ## TA Notes
# Encourage students to think beyond code and include data, environment, documentation, and workflow history.

# %% [markdown]
# ## Troubleshooting Notes
# When students struggle, compare two nearly identical workflows and discuss what information distinguishes them.

# %% [markdown]
# ## Online Delivery Notes
# Exchange reproducibility reports between groups and assess whether replication would be possible.

# %% [markdown]
# ## Stretch Challenge
# Design an automated workflow that generates provenance and reproducibility reports for thousands of datasets.

# %% [markdown]
# ## Transition to Semester Course
# Expands into workflow automation, provenance systems, reproducible cyberinfrastructure, and workflow orchestration.

# %% [markdown]
# ## Faculty Takeaways
# Students should understand that reproducibility depends on metadata, provenance, workflow logging, automation, and disciplined documentation.
