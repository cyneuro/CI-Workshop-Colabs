# %% [markdown]
# # Scaling Scientific Workflows with Cloud, HPC, and Cyberinfrastructure
#
# # STUDENT EDITION v2

# %% [markdown]
# ## Why This Matters
# As datasets grow, researchers must decide when to use laptops, cloud platforms, HPC systems, or national cyberinfrastructure resources. Understanding these choices is essential for modern science.

# %% [markdown]
# ## Learning Objectives
# - Estimate workflow resource needs
# - Compare laptop, cloud, and HPC environments
# - Identify workflow bottlenecks
# - Design scalable workflows
# - Evaluate infrastructure tradeoffs

# %% [markdown]
# ## Workflow Context
# Data Collection → Analysis → Scaling → Cloud/HPC Resources → Collaboration → Scientific Discovery

# %% [markdown]
# ## Activity 1: Resource Estimation

# %%
import pandas as pd
url="https://raw.githubusercontent.com/OpenNeuroDatasets/ds000247/main/participants.tsv"
df=pd.read_csv(url,sep="\t")
print("Rows:",len(df))
print("Memory (bytes):",df.memory_usage(deep=True).sum())

# %% [markdown]
# ### Questions
# - Would this dataset fit on a laptop?
# - What happens if the dataset becomes 1000 times larger?
# - What new challenges emerge?

# %% [markdown]
# ## Activity 2: Infrastructure Comparison
# Compare the strengths and weaknesses of laptops, cloud systems, HPC systems, and national cyberinfrastructure.

# %% [markdown]
# ### Reflection Questions
# - When is a laptop sufficient?
# - When is cloud computing useful?
# - When is HPC appropriate?

# %% [markdown]
# ## Workflow Scaling Exercise
# Design a workflow for analyzing a neuroscience dataset that grows from a classroom project to a multi-institution study.

# %% [markdown]
# ## Bottleneck Analysis
# Identify possible bottlenecks involving storage, memory, compute capacity, networking, software, and collaboration.

# %% [markdown]
# ## Cyberinfrastructure Exploration
# Research one platform such as FABRIC, CloudLab, Chameleon, Open Science Grid, or a university cluster. Summarize its role in scientific workflows.

# %% [markdown]
# ## AI Exploration Activity
# Ask an AI system to recommend infrastructure for a large neuroscience workflow.

# %% [markdown]
# ### AI Critique Questions
# - What assumptions did the AI make?
# - Did the AI justify its recommendations?
# - What important constraints were ignored?

# %% [markdown]
# ## Workflow Design Challenge
# Design a scalable scientific workflow that includes data acquisition, storage, analysis, reproducibility, collaboration, and dissemination.

# %% [markdown]
# ## Reflection
# - What factors influence infrastructure decisions?
# - What tradeoffs arise when scaling workflows?
# - How can reproducibility be preserved as workflows grow?

# %% [markdown]
# ## Stretch Challenge
# Design an architecture supporting thousands of neuroscience datasets, automated provenance capture, AI-assisted analysis, and distributed collaboration.

# %% [markdown]
# ## Looking Ahead
# The next notebook explores machine learning, knowledge discovery, feature engineering, validation, and AI-enabled scientific workflows.
