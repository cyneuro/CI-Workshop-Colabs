# %% [markdown]
# # Workflow Automation, Metadata, Provenance, and Reproducible Research
#
# # STUDENT EDITION v2

# %% [markdown]
# ## Why This Matters
# Scientific discoveries are only useful if others can understand, reproduce, and build upon them. Metadata, provenance, and documentation make science reusable and trustworthy.

# %% [markdown]
# ## Learning Objectives
# - Explain reproducibility
# - Create a metadata inventory
# - Document provenance
# - Build a workflow log
# - Evaluate FAIR principles

# %% [markdown]
# ## Workflow Context
# Data Discovery → Analysis → Documentation → Provenance → Reproducibility → Sharing

# %% [markdown]
# ## Activity 1: Metadata Inventory

# %%
import pandas as pd
url="https://raw.githubusercontent.com/OpenNeuroDatasets/ds000247/main/participants.tsv"
df=pd.read_csv(url,sep="\t")
df.head()

# %% [markdown]
# ### Questions
# - What variables are present?
# - What metadata should accompany the dataset?
# - What information would future researchers need?

# %% [markdown]
# ## Activity 2: Create a Provenance Record
# Document dataset source, access date, repository location, software used, and intended purpose.

# %%
import platform
platform.python_version()

# %% [markdown]
# ## Activity 3: Workflow Logging
# Create a workflow log describing inputs, processing steps, outputs, software environment, and decisions made during analysis.

# %% [markdown]
# ### Reflection Questions
# - What information is easiest to forget?
# - How might missing documentation affect reproducibility?

# %% [markdown]
# ## FAIR Assessment Exercise
# Evaluate the dataset using the FAIR principles: Findable, Accessible, Interoperable, and Reusable.

# %% [markdown]
# ## Reproducibility Challenge
# Imagine another researcher must repeat your work five years from now. What information must be preserved?

# %% [markdown]
# ## AI Exploration Activity
# Ask an AI tool to generate a reproducibility checklist. Compare its recommendations with your workflow documentation.

# %% [markdown]
# ### AI Critique Questions
# - What recommendations seem useful?
# - What important items were omitted?
# - Which recommendations require evidence?

# %% [markdown]
# ## Workflow Design Exercise
# Design a workflow that automatically records provenance, metadata, software versions, and outputs.

# %% [markdown]
# ## Reflection
# - What makes research reproducible?
# - How do metadata and provenance differ?
# - Why are FAIR principles important?

# %% [markdown]
# ## Stretch Challenge
# Design an automated system that generates reproducibility reports for hundreds of datasets and analyses.

# %% [markdown]
# ## Looking Ahead
# The next notebook focuses on scaling workflows using cloud computing, HPC systems, and cyberinfrastructure resources.
