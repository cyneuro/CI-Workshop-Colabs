# %% [markdown]
# # Open Neuroscience Data Repositories and Neuroinformatics Workflows
#
# # STUDENT EDITION v2

# %% [markdown]
# ## Why This Matters
# Modern science depends on well-described, reusable datasets. Understanding repositories, metadata, and provenance helps researchers discover, share, and reuse scientific data.

# %% [markdown]
# ## Learning Objectives
# - Explain the purpose of scientific repositories
# - Describe BIDS and metadata
# - Evaluate dataset documentation
# - Understand provenance concepts
# - Assess data reuse potential

# %% [markdown]
# ## Workflow Context
# Data Discovery → Metadata Review → Access → Analysis → Reproducibility → Sharing

# %% [markdown]
# ## Activity 1: Explore an Open Dataset
# Investigate an openly available neuroscience dataset and identify important variables and metadata.

# %%
import pandas as pd
url="https://raw.githubusercontent.com/OpenNeuroDatasets/ds000247/main/participants.tsv"
df=pd.read_csv(url,sep="\t")
df.head()

# %% [markdown]
# ### Questions
# - What variables are available?
# - Which variables appear most informative?
# - What additional metadata would be useful?

# %%
df.columns

# %% [markdown]
# ## Repository Investigation
# Visit an OpenNeuro dataset and identify evidence of documentation, metadata, organization, and reuse support.

# %% [markdown]
# ### Reflection Questions
# - How easily can a new researcher understand this dataset?
# - What information would improve reuse?

# %% [markdown]
# ## BIDS Exploration
# Research the purpose of BIDS (Brain Imaging Data Structure). How does standardization support reproducibility?

# %% [markdown]
# ## Provenance Activity
# Create a brief provenance record containing dataset source, access date, repository information, and intended use.

# %% [markdown]
# ## Metadata Evaluation Exercise
# Evaluate dataset metadata for completeness, clarity, interoperability, and reusability.

# %% [markdown]
# ## AI Exploration Activity
# Ask an AI tool to evaluate the dataset. Compare its conclusions with the evidence available from metadata and documentation.

# %% [markdown]
# ### AI Critique Questions
# - Which claims are supported?
# - Which claims require additional evidence?
# - What information is missing?

# %% [markdown]
# ## Workflow Design Challenge
# Design a workflow for discovering, documenting, analyzing, and sharing neuroscience datasets.

# %% [markdown]
# ## Reflection
# - Why does metadata matter?
# - What role does provenance play?
# - How do repositories support reproducible science?

# %% [markdown]
# ## Stretch Challenge
# Design an automated workflow that catalogs hundreds of neuroscience datasets while preserving provenance and metadata.

# %% [markdown]
# ## Looking Ahead
# The next notebook focuses on exploratory data analysis, visualization, interpretation, and AI-assisted scientific discovery.
