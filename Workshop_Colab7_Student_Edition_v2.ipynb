# %% [markdown]
# # Cloud-to-Edge Workflows, Embedded Analytics, and Distributed Cyberinfrastructure
#
# # STUDENT EDITION v2

# %% [markdown]
# ## Why This Matters
# Modern scientific systems often include sensors, edge devices, cloud resources, AI services, and users. Understanding how computation is distributed helps researchers design efficient workflows.

# %% [markdown]
# ## Learning Objectives
# - Explain cloud, edge, and HPC concepts
# - Analyze workflow placement decisions
# - Identify latency and bandwidth tradeoffs
# - Design distributed workflows
# - Evaluate AI-assisted architectures

# %% [markdown]
# ## Workflow Context
# Sensors → Edge Devices → Cloud Resources → HPC Systems → AI Services → Scientific Discovery

# %% [markdown]
# ## Activity 1: Understanding Workflow Layers

# %% [markdown]
# Describe which tasks belong at the sensor, edge, cloud, and HPC levels. Explain your reasoning.

# %%
workflow_layers = ["Sensor","Edge","Cloud","HPC"]
workflow_layers

# %% [markdown]
# ## Activity 2: Neuroscience Workflow Design
# Design a workflow for mobile EEG monitoring using wearable devices, cloud storage, and machine learning.

# %% [markdown]
# ### Questions
# - What should be processed locally?
# - What should be sent to the cloud?
# - What requires large-scale computing resources?

# %% [markdown]
# ## Activity 3: Cloud-to-Edge Analysis
# Compare advantages and disadvantages of edge processing versus centralized cloud processing.

# %% [markdown]
# ### Reflection Questions
# - Why might local processing be valuable?
# - What are the limitations of edge devices?

# %% [markdown]
# ## Environmental Monitoring Case Study
# Consider a network of environmental sensors. Decide which information should be processed locally and which should be transmitted.

# %% [markdown]
# ## Robotics and micro:bit Activity
# Design a workflow using micro:bit and Cutebot devices that collect sensor data, make decisions, and communicate with cloud services.

# %% [markdown]
# ## AI Exploration Activity
# Ask an AI tool to design a cloud-to-edge workflow for continuous monitoring of neuroscience or environmental data.

# %% [markdown]
# ### AI Critique Questions
# - Did the AI justify workflow placement decisions?
# - Were bandwidth, latency, and scalability considered?
# - What assumptions were made?

# %% [markdown]
# ## Workflow Design Challenge
# Create a complete architecture diagram showing sensors, edge devices, cloud resources, storage, AI components, and users.

# %% [markdown]
# ## Reflection
# - What determines where computation should occur?
# - How do cloud and edge computing complement each other?
# - How can distributed workflows remain reproducible?

# %% [markdown]
# ## Stretch Challenge
# Design a workflow supporting 100,000 sensors, AI inference, automated provenance capture, cloud storage, and HPC model training.

# %% [markdown]
# ## Looking Ahead
# The final notebook focuses on FAIR principles, benchmarking, workflow validation, auditing, and trustworthy AI.
