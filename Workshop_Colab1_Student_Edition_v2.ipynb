# %% [markdown]
# # Scientific Workflows and NeuroCyberinfrastructure Foundations
#
# # STUDENT EDITION v2

# %% [markdown]
# ## Why This Matters
# Modern science depends on workflows that connect data, computation, AI, reproducibility, and sharing. Understanding workflows helps researchers produce trustworthy and reusable results.

# %% [markdown]
# ## Learning Objectives
# - Define a scientific workflow
# - Identify workflow stages
# - Explain reproducibility
# - Describe cyberinfrastructure concepts
# - Evaluate AI roles in workflows

# %% [markdown]
# ## Workflow Context
# Data Acquisition → Processing → Analysis → Visualization → Interpretation → Reproducibility → Sharing

# %% [markdown]
# ## Activity 1: What Is a Workflow?
# Draw a workflow for a neuroscience study. Identify inputs, processing steps, outputs, and sharing mechanisms.

# %% [markdown]
# ### Reflection Questions
# 1. Where does the workflow begin?
# 2. Where does it end?
# 3. Which steps are easiest to forget?

# %%
import pandas as pd
url="https://raw.githubusercontent.com/OpenNeuroDatasets/ds000247/main/participants.tsv"
df=pd.read_csv(url,sep="\t")
df.head()

# %% [markdown]
# ## Activity 2: Exploring Scientific Data
# Examine the dataset and identify data fields that may be useful for future scientific studies.

# %% [markdown]
# ### Questions
# - What information is provided?
# - What information is missing?
# - How could another researcher reuse this dataset?

# %%
df.columns

# %% [markdown]
# ## Scientific Workflow Challenge
# Map how this dataset would move through a complete scientific workflow from collection to publication.

# %% [markdown]
# ## AI Exploration Activity
# Use an AI system to explain the dataset and propose three scientific questions. Compare the AI response with the evidence actually available in the dataset.

# %% [markdown]
# ### AI Critique Questions
# - Which statements were supported by evidence?
# - Which statements lacked evidence?
# - What additional information would improve confidence?

# %% [markdown]
# ## Workflow Design Exercise
# Design a workflow for a neuroscience project involving data collection, storage, analysis, visualization, reproducibility, and sharing.

# %% [markdown]
# ## Reflection
# - What did you learn about workflows?
# - Why is reproducibility important?
# - What role can AI play in scientific workflows?

# %% [markdown]
# ## Stretch Challenge
# Redesign your workflow for a project involving 1,000 datasets and a multi-institution collaboration.

# %% [markdown]
# ## Looking Ahead
# The next notebook introduces OpenNeuro, BIDS, metadata, provenance, and neuroinformatics workflows.
