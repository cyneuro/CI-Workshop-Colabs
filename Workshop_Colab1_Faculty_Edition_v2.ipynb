# %% [markdown]
# # Scientific Workflows and NeuroCyberinfrastructure Foundations
#
# # FACULTY EDITION v2

# %% [markdown]
# ## Teaching Narrative
# This foundational notebook introduces scientific workflow thinking. Students should learn that science is not a collection of tools but a structured workflow connecting data, computation, interpretation, reproducibility, and sharing.

# %% [markdown]
# ## Workshop Context
# Colab 1 establishes workflow thinking that supports all subsequent workshop activities including repositories, AI, reproducibility, cloud computing, machine learning, edge workflows, and validation.

# %% [markdown]
# ## NSF CyberTraining Alignment
# Scientific workflows, cyberinfrastructure, open science, AI-assisted discovery, reproducibility, and computational thinking.

# %% [markdown]
# ## Learning Outcomes
# - Define a scientific workflow
# - Identify inputs, transformations, and outputs
# - Explain reproducibility
# - Describe AI roles in workflows
# - Explain cyberinfrastructure concepts

# %% [markdown]
# ## Instructor Delivery Guide
# 0-10 Motivation
# 10-25 Workflow concepts
# 25-40 Dataset exploration
# 40-55 Workflow construction
# 55-70 AI-assisted science
# 70-80 Reflection

# %% [markdown]
# ## Activity Timing Guide
# Activity 1: 10 min
# Activity 2: 15 min
# Activity 3: 15 min
# Activity 4: 10 min
# Discussion: 20 min

# %% [markdown]
# ## Common Misconceptions
# 1. Workflows are the same as code.
# 2. Analysis is the entire workflow.
# 3. Reproducibility can be added later.
# 4. AI replaces scientific reasoning.

# %% [markdown]
# ## Workflow Framework
# Input → Acquisition → Processing → Analysis → Visualization → Interpretation → Reproducibility → Sharing

# %% [markdown]
# ## Activity 1
# Identify inputs, transformations, and outputs for a neuroscience study.

# %% [markdown]
# ### Faculty Solution
# Input: data and metadata
# Transformations: cleaning, analysis, visualization
# Outputs: results, figures, knowledge products

# %% [markdown]
# ## Facilitation Notes
# Encourage students to identify stages beyond analysis, particularly acquisition, metadata, documentation, and dissemination.

# %%
import pandas as pd
url="https://raw.githubusercontent.com/OpenNeuroDatasets/ds000247/main/participants.tsv"
df=pd.read_csv(url,sep="\t")
df.head()

# %% [markdown]
# ## Activity 2 Faculty Solution
# Expected observations include participant identifiers, demographic metadata, and the role of metadata in enabling reuse.

# %% [markdown]
# ## Strong Student Response
# Recognizes both data and metadata as workflow inputs and discusses reproducibility implications.

# %% [markdown]
# ## Average Student Response
# Identifies data fields but does not connect them to workflow goals.

# %% [markdown]
# ## Weak Student Response
# Focuses only on coding or software.

# %% [markdown]
# ## Discussion Prompts
# - Where does science begin in a workflow?
# - Is data collection part of a workflow?
# - What happens after analysis?
# - Why does reproducibility matter?

# %% [markdown]
# ## AI Facilitation Guide
# Prompt: Explain this dataset and suggest three scientific questions.
# Have participants critique strengths, assumptions, and limitations.

# %% [markdown]
# ## Common AI Hallucinations
# - Inventing findings
# - Overstating significance
# - Inferring information not contained in metadata
# - Confusing workflow stages

# %% [markdown]
# ## Sample AI Evaluation
# Students should evaluate accuracy, completeness, limitations, and evidence.

# %% [markdown]
# ## TA Notes
# Redirect tool-centric discussions toward workflow-centric reasoning.

# %% [markdown]
# ## Troubleshooting Notes
# If students struggle, ask them to describe the process from data acquisition to publication.

# %% [markdown]
# ## Online Delivery Notes
# Use breakout groups to compare workflow diagrams and discuss differences.

# %% [markdown]
# ## Stretch Challenge
# Redesign the workflow for 1000 datasets and a multi-institution collaboration.

# %% [markdown]
# ## Transition to Semester Course
# Expands into workflow engineering, neuroinformatics, cloud computing, AI workflows, reproducibility engineering, and distributed systems.

# %% [markdown]
# ## Faculty Takeaways
# Students should leave understanding that workflows are the organizing principle connecting data, AI, cyberinfrastructure, and scientific discovery.
