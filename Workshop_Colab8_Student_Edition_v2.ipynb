# %% [markdown]
# # FAIR, Validation, Benchmarking, and Trustworthy AI Workflows
#
# # STUDENT EDITION v2

# %% [markdown]
# ## Why This Matters
# Scientific results should be trustworthy, reproducible, reusable, and transparent. FAIR practices, benchmarking, validation, and responsible AI use help ensure high-quality science.

# %% [markdown]
# ## Learning Objectives
# - Apply FAIR principles
# - Evaluate workflow trustworthiness
# - Understand benchmarking concepts
# - Assess AI-generated claims
# - Conduct workflow audits

# %% [markdown]
# ## Workflow Context
# Data → Analysis → Validation → Benchmarking → FAIR Assessment → Trustworthy Science

# %% [markdown]
# ## Activity 1: FAIR Assessment

# %%
fair_principles=["Findable","Accessible","Interoperable","Reusable"]
fair_principles

# %% [markdown]
# ### Questions
# - Is the dataset easy to find?
# - Is it accessible?
# - Can it interoperate with other tools?
# - Can others reuse it?

# %% [markdown]
# ## Activity 2: Workflow Audit
# Create a checklist containing dataset source, metadata, software versions, parameters, outputs, provenance, and documentation.

# %% [markdown]
# ## Activity 3: Validation Review
# Identify inputs, assumptions, processing steps, outputs, and interpretations that should be validated.

# %% [markdown]
# ### Reflection Questions
# - Can a workflow be reproducible and still be wrong?
# - What evidence increases trust?

# %% [markdown]
# ## Benchmarking Exercise
# Compare two hypothetical workflows based on runtime, reproducibility, scalability, documentation quality, and robustness.

# %% [markdown]
# ## Reproducibility Challenge
# Imagine another team must reproduce your results several years from now. What information must be preserved?

# %% [markdown]
# ## AI Exploration Activity
# Ask an AI system to review a workflow and identify strengths, risks, and limitations.

# %% [markdown]
# ### AI Critique Questions
# - What evidence supports the AI conclusions?
# - What assumptions were made?
# - Which recommendations require verification?

# %% [markdown]
# ## Trustworthy AI Checklist
# Evaluate transparency, documentation, uncertainty reporting, limitations, validation, and human oversight.

# %% [markdown]
# ## Workflow Design Challenge
# Design a workflow that automatically records metadata, provenance, validation evidence, benchmarking results, and reproducibility artifacts.

# %% [markdown]
# ## Reflection
# - What makes a workflow trustworthy?
# - How do validation and benchmarking differ?
# - Why are FAIR principles important?

# %% [markdown]
# ## Stretch Challenge
# Design an automated workflow auditing system that evaluates thousands of datasets and AI-enabled analyses.

# %% [markdown]
# ## Workshop Capstone Reflection
# Review how workflows, repositories, analysis, reproducibility, scaling, machine learning, cloud-to-edge systems, and trustworthy AI fit together.

# %% [markdown]
# ## Looking Forward
# These concepts provide a foundation for advanced study in cyberinfrastructure, workflow engineering, AI-enabled science, and computational neuroscience.
